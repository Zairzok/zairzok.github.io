# %% [markdown]
# ## HW10

# %%
import altair as alt

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_bcubcg_fall2022/main/data/building_inventory.csv')
df.head()
# Out:
#                        Agency Name  \
# 0  Department of Natural Resources
# 1  Department of Natural Resources
# 2  Department of Natural Resources
# 3  Department of Natural Resources
# 4  Department of Natural Resources
#
#                                      Location Name             Address  \
# 0  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 1  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 2  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 3  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 4  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
#
#       City  Zip code  County  Congress Dist Congressional Full Name  Rep Dist  \
# 0  Astoria     61501  Fulton             17            Cheri Bustos        93
# 1  Astoria     61501  Fulton             17            Cheri Bustos        93
# 2  Astoria     61501  Fulton             17            Cheri Bustos        93
# ...

# %%
mobility_url = 'https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_bcubcg_fall2022/main/data/building_inventory.csv'

# %%
scatter1 = alt.Chart(mobility_url).mark_point().encode(
    x='Congress Dist:Q',
    y=alt.Y('Year Acquired:T',scale=alt.Scale(type='log'))
)
scatter1
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Example with interactivity

# %% [markdown]
# ``` python
# (
#     "data": {"url": "https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_bcubcg_fall2022/main/data/building_inventory.csv"},"hconcat":[
#         {
#             "params": [{"name": "brush", "select": "interval"}],
#             "description": "Attempt#1.",
#             "height":"400",
#             "mark": "point",
#             "encoding": {
#                 "x":{"field":"Agency Name", "type":"ordinal"},
#                 "y":{"aggregate":"mean", "field":"Year Constructed", "type": "temporal"},
#             }
#         },
#         {
#             "transform": [{"filter": {"param": "brush"}}],
#             "description": "Histogram Attempt #1",
#             "height":"300",
#             "mark": "bar",
#             "encoding": {
#                 "x": {"bin": True, "field": "Rep Dist", "type": "quantitative", "title":"Count of Rep Dist"},
#                 "y": {
#                     "aggregate":"count",
#                     "type": "quantitative",
#                     "axis": {"title": "Histogram"}
#                 }
#             }
#         }
#     ]
# )
# ```

# %%
chart1 = alt.Chart(mobility_url).mark_point().encode(
    alt.X("Agency Name:O"),
    alt.Y("Year Constructed:T"),
).properties(
    height=400
)

chart1
# Out:
# alt.Chart(...)

# %%
chart1.save('C:/Users/japet/zairzok.github.io/assets/json/chart1.json')

# %%
chart2 = alt.Chart(mobility_url).mark_bar().encode(
    alt.X("Rep Dist:Q",bin=True,axis=alt.Axis(title="Count of Dist Rep")),
    alt.Y('count()',axis=alt.Axis(title='Histogram')),
)

chart2
# Out:
# alt.Chart(...)

# %%
brush = alt.selection_interval(encodings=['x','y'])

chart1 = alt.Chart(mobility_url).mark_point().encode(
    alt.X("Agency Name:O"),
    alt.Y("Year Constructed:T"),
).properties(
    height=800
).add_selection(
brush
)

chart2 = alt.Chart(mobility_url).mark_bar().encode(
    alt.X("Rep Dist:Q",bin=True,axis=alt.Axis(title="Count of Dist Rep")),
    alt.Y('count()',axis=alt.Axis(title='Histogram')),
).transform_filter(
    brush
)

chart = chart1.properties(width=300) | chart2.properties(width=300)

chart
# Out:
# alt.HConcatChart(...)

# %%
chart.save('C:/Users/japet/zairzok.github.io/assets/json/chart_interactive.json')

# %%
chart3 = alt.Chart(mobility_url).mark_bar().encode(
    alt.X("Agency Name:O"),
    alt.Y('count()',axis=alt.Axis(title='Count of Agencies in Dataset')),
).properties(
    height=400
)

chart3
# Out:
# alt.Chart(...)

# %%
chart3.save('C:/Users/japet/zairzok.github.io/assets/json/chart_static.json')
